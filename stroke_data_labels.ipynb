# %% [markdown]
# Change column contents from integers to strings, upload csv to SQL

# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# read csv file
df = pd.read_csv("./Datasets/train_strokes.csv")

# %%
# drop id column
df.drop(['id'], axis=1, inplace=True)
df
# Out:
#        gender   age  hypertension  heart_disease ever_married     work_type  \
# 0        Male   3.0             0              0           No      children
# 1        Male  58.0             1              0          Yes       Private
# 2      Female   8.0             0              0           No       Private
# 3      Female  70.0             0              0          Yes       Private
# 4        Male  14.0             0              0           No  Never_worked
# ...       ...   ...           ...            ...          ...           ...
# 43395  Female  10.0             0              0           No      children
# 43396  Female  56.0             0              0          Yes      Govt_job
# 43397  Female  82.0             1              0          Yes       Private
# 43398    Male  40.0             0              0          Yes       Private
# 43399  Female  82.0             0              0          Yes       Private
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0              Rural              95.12  18.0              NaN       0
# 1              Urban              87.96  39.2     never smoked       0
# 2              Urban             110.89  17.6              NaN       0
# 3              Rural              69.04  35.9  formerly smoked       0
# 4              Rural             161.28  19.1              NaN       0
# ...              ...                ...   ...              ...     ...
# 43395          Urban              58.64  20.4     never smoked       0
# 43396          Urban             213.61  55.4  formerly smoked       0
# 43397          Urban              91.94  28.9  formerly smoked       0
# 43398          Urban              99.16  33.2     never smoked       0
# 43399          Urban              79.48  20.6     never smoked       0
#
# [43400 rows x 11 columns]

# %%
#https://stackoverflow.com/questions/32589829/how-to-get-value-counts-for-multiple-columns-at-once-in-pandas-dataframe
cat_cols = df.select_dtypes(include=object).columns.tolist()
(pd.DataFrame(
    df[cat_cols]
    .melt(var_name='column', value_name='value')
    .value_counts())
.rename(columns={0: 'counts'})
.sort_values(by=['column', 'counts']))
# Out:
#                                 counts
# column         value
# Residence_type Rural             21644
#                Urban             21756
# ever_married   No                15462
#                Yes               27938
# gender         Other                11
#                Male              17724
#                Female            25665
# smoking_status smokes             6562
#                formerly smoked    7493
#                never smoked      16053
# work_type      Never_worked        177
#                Govt_job           5440
#                children           6156
#                Self-employed      6793
#                Private           24834

# %%
# drop 'other' gender - we do not know the premise of that selection
df = df[df.gender != 'Other']
print(f"{df['gender'].value_counts()}")
# Out:
# Female    25665
# Male      17724
# Name: gender, dtype: int64

# %%
# merge 'children' and 'Never_worked' categories
df = df.replace({'work_type': {'Never_worked':'Never_worked', 'children': 'Never_worked'}})
df
# Out:
#        gender   age  hypertension  heart_disease ever_married     work_type  \
# 0        Male   3.0             0              0           No  Never_worked
# 1        Male  58.0             1              0          Yes       Private
# 2      Female   8.0             0              0           No       Private
# 3      Female  70.0             0              0          Yes       Private
# 4        Male  14.0             0              0           No  Never_worked
# ...       ...   ...           ...            ...          ...           ...
# 43395  Female  10.0             0              0           No  Never_worked
# 43396  Female  56.0             0              0          Yes      Govt_job
# 43397  Female  82.0             1              0          Yes       Private
# 43398    Male  40.0             0              0          Yes       Private
# 43399  Female  82.0             0              0          Yes       Private
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0              Rural              95.12  18.0              NaN       0
# 1              Urban              87.96  39.2     never smoked       0
# 2              Urban             110.89  17.6              NaN       0
# 3              Rural              69.04  35.9  formerly smoked       0
# 4              Rural             161.28  19.1              NaN       0
# ...              ...                ...   ...              ...     ...
# 43395          Urban              58.64  20.4     never smoked       0
# 43396          Urban             213.61  55.4  formerly smoked       0
# 43397          Urban              91.94  28.9  formerly smoked       0
# 43398          Urban              99.16  33.2     never smoked       0
# 43399          Urban              79.48  20.6     never smoked       0
#
# [43389 rows x 11 columns]

# %%
# change hypertension answer from integers to string
df['hypertension'] = df['hypertension'].replace({0: 'No', 1: 'Yes'})
df
# Out:
#        gender   age hypertension  heart_disease ever_married     work_type  \
# 0        Male   3.0           No              0           No  Never_worked
# 1        Male  58.0          Yes              0          Yes       Private
# 2      Female   8.0           No              0           No       Private
# 3      Female  70.0           No              0          Yes       Private
# 4        Male  14.0           No              0           No  Never_worked
# ...       ...   ...          ...            ...          ...           ...
# 43395  Female  10.0           No              0           No  Never_worked
# 43396  Female  56.0           No              0          Yes      Govt_job
# 43397  Female  82.0          Yes              0          Yes       Private
# 43398    Male  40.0           No              0          Yes       Private
# 43399  Female  82.0           No              0          Yes       Private
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0              Rural              95.12  18.0              NaN       0
# 1              Urban              87.96  39.2     never smoked       0
# 2              Urban             110.89  17.6              NaN       0
# 3              Rural              69.04  35.9  formerly smoked       0
# 4              Rural             161.28  19.1              NaN       0
# ...              ...                ...   ...              ...     ...
# 43395          Urban              58.64  20.4     never smoked       0
# 43396          Urban             213.61  55.4  formerly smoked       0
# 43397          Urban              91.94  28.9  formerly smoked       0
# 43398          Urban              99.16  33.2     never smoked       0
# 43399          Urban              79.48  20.6     never smoked       0
#
# [43389 rows x 11 columns]

# %%
# change heart_disease answer from integers to string
df['heart_disease'] = df['heart_disease'].replace({0: 'No', 1: 'Yes'})
df
# Out:
#        gender   age hypertension heart_disease ever_married     work_type  \
# 0        Male   3.0           No            No           No  Never_worked
# 1        Male  58.0          Yes            No          Yes       Private
# 2      Female   8.0           No            No           No       Private
# 3      Female  70.0           No            No          Yes       Private
# 4        Male  14.0           No            No           No  Never_worked
# ...       ...   ...          ...           ...          ...           ...
# 43395  Female  10.0           No            No           No  Never_worked
# 43396  Female  56.0           No            No          Yes      Govt_job
# 43397  Female  82.0          Yes            No          Yes       Private
# 43398    Male  40.0           No            No          Yes       Private
# 43399  Female  82.0           No            No          Yes       Private
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0              Rural              95.12  18.0              NaN       0
# 1              Urban              87.96  39.2     never smoked       0
# 2              Urban             110.89  17.6              NaN       0
# 3              Rural              69.04  35.9  formerly smoked       0
# 4              Rural             161.28  19.1              NaN       0
# ...              ...                ...   ...              ...     ...
# 43395          Urban              58.64  20.4     never smoked       0
# 43396          Urban             213.61  55.4  formerly smoked       0
# 43397          Urban              91.94  28.9  formerly smoked       0
# 43398          Urban              99.16  33.2     never smoked       0
# 43399          Urban              79.48  20.6     never smoked       0
#
# [43389 rows x 11 columns]

# %%
# change stroke answer from integers to string
df['stroke'] = df['stroke'].replace({0: 'No', 1: 'Yes'})
df
# Out:
#        gender   age hypertension heart_disease ever_married     work_type  \
# 0        Male   3.0           No            No           No  Never_worked
# 1        Male  58.0          Yes            No          Yes       Private
# 2      Female   8.0           No            No           No       Private
# 3      Female  70.0           No            No          Yes       Private
# 4        Male  14.0           No            No           No  Never_worked
# ...       ...   ...          ...           ...          ...           ...
# 43395  Female  10.0           No            No           No  Never_worked
# 43396  Female  56.0           No            No          Yes      Govt_job
# 43397  Female  82.0          Yes            No          Yes       Private
# 43398    Male  40.0           No            No          Yes       Private
# 43399  Female  82.0           No            No          Yes       Private
#
#       Residence_type  avg_glucose_level   bmi   smoking_status stroke
# 0              Rural              95.12  18.0              NaN     No
# 1              Urban              87.96  39.2     never smoked     No
# 2              Urban             110.89  17.6              NaN     No
# 3              Rural              69.04  35.9  formerly smoked     No
# 4              Rural             161.28  19.1              NaN     No
# ...              ...                ...   ...              ...    ...
# 43395          Urban              58.64  20.4     never smoked     No
# 43396          Urban             213.61  55.4  formerly smoked     No
# 43397          Urban              91.94  28.9  formerly smoked     No
# 43398          Urban              99.16  33.2     never smoked     No
# 43399          Urban              79.48  20.6     never smoked     No
#
# [43389 rows x 11 columns]

# %%
df = df.fillna(0)

df[(df['bmi'] == 0) & (df['stroke'] == 1)]
# Out:
# Empty DataFrame
# Columns: [gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
#https://stackoverflow.com/questions/39690742/convert-float-to-int-and-leave-nulls
#df['b'] = df['b'].astype('Int64')

df['bmi'] = df['bmi'].values.astype(int)
df
# Out:
#        gender   age hypertension heart_disease ever_married     work_type  \
# 0        Male   3.0           No            No           No  Never_worked
# 1        Male  58.0          Yes            No          Yes       Private
# 2      Female   8.0           No            No           No       Private
# 3      Female  70.0           No            No          Yes       Private
# 4        Male  14.0           No            No           No  Never_worked
# ...       ...   ...          ...           ...          ...           ...
# 43395  Female  10.0           No            No           No  Never_worked
# 43396  Female  56.0           No            No          Yes      Govt_job
# 43397  Female  82.0          Yes            No          Yes       Private
# 43398    Male  40.0           No            No          Yes       Private
# 43399  Female  82.0           No            No          Yes       Private
#
#       Residence_type  avg_glucose_level  bmi   smoking_status stroke
# 0              Rural              95.12   18                0     No
# 1              Urban              87.96   39     never smoked     No
# 2              Urban             110.89   17                0     No
# 3              Rural              69.04   35  formerly smoked     No
# 4              Rural             161.28   19                0     No
# ...              ...                ...  ...              ...    ...
# 43395          Urban              58.64   20     never smoked     No
# 43396          Urban             213.61   55  formerly smoked     No
# 43397          Urban              91.94   28  formerly smoked     No
# 43398          Urban              99.16   33     never smoked     No
# 43399          Urban              79.48   20     never smoked     No
#
# [43389 rows x 11 columns]

# %%
# check to see how many 0's are in the 'bmi' column
df[(df['bmi'] == 0) & (df['stroke'] == 1)]
# Out:
# Empty DataFrame
# Columns: [gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
# Replace 'bmi' 0 values with mean of bmi
mean_bmi = np.round(df['bmi'].mean())
print(mean_bmi)
# Out:
# 27.0

# %%
# Replace 'bmi' 0 values with mean of bmi
df['bmi'] = df['bmi'].replace(0, mean_bmi)
df
# Out:
#        gender   age hypertension heart_disease ever_married     work_type  \
# 0        Male   3.0           No            No           No  Never_worked
# 1        Male  58.0          Yes            No          Yes       Private
# 2      Female   8.0           No            No           No       Private
# 3      Female  70.0           No            No          Yes       Private
# 4        Male  14.0           No            No           No  Never_worked
# ...       ...   ...          ...           ...          ...           ...
# 43395  Female  10.0           No            No           No  Never_worked
# 43396  Female  56.0           No            No          Yes      Govt_job
# 43397  Female  82.0          Yes            No          Yes       Private
# 43398    Male  40.0           No            No          Yes       Private
# 43399  Female  82.0           No            No          Yes       Private
#
#       Residence_type  avg_glucose_level  bmi   smoking_status stroke
# 0              Rural              95.12   18                0     No
# 1              Urban              87.96   39     never smoked     No
# 2              Urban             110.89   17                0     No
# 3              Rural              69.04   35  formerly smoked     No
# 4              Rural             161.28   19                0     No
# ...              ...                ...  ...              ...    ...
# 43395          Urban              58.64   20     never smoked     No
# 43396          Urban             213.61   55  formerly smoked     No
# 43397          Urban              91.94   28  formerly smoked     No
# 43398          Urban              99.16   33     never smoked     No
# 43399          Urban              79.48   20     never smoked     No
#
# [43389 rows x 11 columns]

# %%
# All NaN werer replaced with 0, so we need to replace 0 in 'smoking_status' column to 'unknown'
df['smoking_status'] = df['smoking_status'].replace(to_replace=0, value="unknown")

# %%
df[(df['smoking_status'] == 'unknown') & (df['stroke'] == 1)]
# Out:
# Empty DataFrame
# Columns: [gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
df.describe()
# Out:
#                 age  avg_glucose_level           bmi
# count  43389.000000       43389.000000  43389.000000
# mean      42.219747         104.486760     28.116804
# std       22.520750          43.115157      7.640829
# min        0.080000          55.000000     10.000000
# 25%       24.000000          77.540000     23.000000
# 50%       44.000000          91.580000     27.000000
# 75%       60.000000         112.070000     32.000000
# max       82.000000         291.050000     97.000000

# %%
# bin avg_glucose_level
avg_glucose_lvl = df['avg_glucose_level']
glucose_lvl_bins = [0, 69, 100, 126, 292]
glucose_lvl_labels = ['<70','70-100','101-125','>126']

df['avg_glucose_level'] = pd.cut(avg_glucose_lvl, bins=glucose_lvl_bins, labels=glucose_lvl_labels)
df
# Out:
#        gender   age hypertension heart_disease ever_married     work_type  \
# 0        Male   3.0           No            No           No  Never_worked
# 1        Male  58.0          Yes            No          Yes       Private
# 2      Female   8.0           No            No           No       Private
# 3      Female  70.0           No            No          Yes       Private
# 4        Male  14.0           No            No           No  Never_worked
# ...       ...   ...          ...           ...          ...           ...
# 43395  Female  10.0           No            No           No  Never_worked
# 43396  Female  56.0           No            No          Yes      Govt_job
# 43397  Female  82.0          Yes            No          Yes       Private
# 43398    Male  40.0           No            No          Yes       Private
# 43399  Female  82.0           No            No          Yes       Private
#
#       Residence_type avg_glucose_level  bmi   smoking_status stroke
# 0              Rural            70-100   18          unknown     No
# 1              Urban            70-100   39     never smoked     No
# 2              Urban           101-125   17          unknown     No
# 3              Rural            70-100   35  formerly smoked     No
# 4              Rural              >126   19          unknown     No
# ...              ...               ...  ...              ...    ...
# 43395          Urban               <70   20     never smoked     No
# 43396          Urban              >126   55  formerly smoked     No
# 43397          Urban            70-100   28  formerly smoked     No
# 43398          Urban            70-100   33     never smoked     No
# 43399          Urban            70-100   20     never smoked     No
#
# [43389 rows x 11 columns]

# %%
# check null values
for i in df.columns:
    x = df[i].isna().value_counts()
    print("Column name is:",i,"and the amount of null values is:",x)
# Out:
# Column name is: gender and the amount of null values is: False    43389
# Name: gender, dtype: int64
# Column name is: age and the amount of null values is: False    43389
# Name: age, dtype: int64
# Column name is: hypertension and the amount of null values is: False    43389
# Name: hypertension, dtype: int64
# Column name is: heart_disease and the amount of null values is: False    43389
# Name: heart_disease, dtype: int64
# Column name is: ever_married and the amount of null values is: False    43389
# Name: ever_married, dtype: int64
# Column name is: work_type and the amount of null values is: False    43389
# Name: work_type, dtype: int64
# Column name is: Residence_type and the amount of null values is: False    43389
# Name: Residence_type, dtype: int64
# Column name is: avg_glucose_level and the amount of null values is: False    43389
# Name: avg_glucose_level, dtype: int64
# Column name is: bmi and the amount of null values is: False    43389
# Name: bmi, dtype: int64
# Column name is: smoking_status and the amount of null values is: False    43389
# Name: smoking_status, dtype: int64
# Column name is: stroke and the amount of null values is: False    43389
# Name: stroke, dtype: int64

# %%
#https://stackoverflow.com/questions/32589829/how-to-get-value-counts-for-multiple-columns-at-once-in-pandas-dataframe
cat_cols = df.select_dtypes(include=object).columns.tolist()
(pd.DataFrame(
    df[cat_cols]
    .melt(var_name='column', value_name='value')
    .value_counts())
.rename(columns={0: 'counts'})
.sort_values(by=['column', 'counts']))
# Out:
#                                 counts
# column         value
# Residence_type Rural             21638
#                Urban             21751
# ever_married   No                15456
#                Yes               27933
# gender         Male              17724
#                Female            25665
# heart_disease  Yes                2062
#                No                41327
# hypertension   Yes                4061
#                No                39328
# smoking_status smokes             6561
#                formerly smoked    7487
#                unknown           13290
#                never smoked      16051
# stroke         Yes                 783
#                No                42606
# work_type      Govt_job           5438
#                Never_worked       6331
#                Self-employed      6793
#                Private           24827

# %%
# save csv

#df.to_csv('Datasets/train_stroke_data_labels.csv', index=True)

# %% [markdown]
# Transfer Data to SQL

# %%
stroke_data = pd.read_csv("Datasets/train_stroke_data_labels.csv")

# %%
from sqlalchemy import create_engine
from config import db_password
import time

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/strokerisk"

# %%
engine = create_engine(db_string)

# %%
stroke_data.to_sql(name='stroke_data_labels', con=engine)
